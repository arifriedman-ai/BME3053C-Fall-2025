# %% [markdown]
# # Patient Records ManagementIn this notebook, we will explore the `PatientRecords` class implemented in the `src/patient_records.py` file. This class allows for managing patient records, including adding, updating, and retrieving records, along with performing basic statistical analysis.

# %% [markdown]
# ## Overview of the PatientRecords ClassThe `PatientRecords` class provides the following functionalities:- **Adding Records**: Add new patient records with data validation.- **Updating Records**: Update existing patient records.- **Retrieving Records**: Retrieve patient records based on various criteria.- **Statistical Analysis**: Perform basic statistical analysis on patient data.

# %% [markdown]
# ## Example UsageBelow are examples of how to use the `PatientRecords` class. Make sure to run the code in the `src/patient_records.py` file first to define the class.

# %%
from src.patient_records import PatientRecords# Create an instance of PatientRecordspatient_records = PatientRecords()# Adding a patient recordpatient_records.add_record({'name': 'John Doe', 'age': 30, 'weight': 70, 'height': 1.75})# Updating a patient recordpatient_records.update_record(0, {'weight': 75})# Retrieving all patient recordsall_records = patient_records.get_all_records()print(all_records)# Performing statistical analysisaverage_age = patient_records.calculate_average_age()print('Average Age:', average_age)

# %% [markdown]
# ## Exercises1. **Add a new patient record**: Use the `add_record` method to add a new patient with your own data.2. **Update an existing record**: Modify the weight of a patient record you added.3. **Retrieve records**: Use the `get_all_records` method to display all patient records.4. **Statistical Analysis**: Calculate and print the average age of all patients.

# %% [markdown]
# ## ConclusionIn this notebook, we have covered the basic usage of the `PatientRecords` class. You can extend this functionality further by adding more features or improving the existing methods.
